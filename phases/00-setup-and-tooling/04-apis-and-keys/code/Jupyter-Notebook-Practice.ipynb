# %% [markdown]
# **Explore in notebook, ship in script**

# %% [markdown]
# 1. Explore data in a notebook
# 2. Prototype your model in the notebook
# 3. Once it works, move the code to .py files
# 4. Import those .py files back into the notebook for further experiments

# %%
# %%timeit 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data = np.random.randn(1000)
data.mean(), data.std()

# %%
df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df

# %%
plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.show()

# %%
from IPython.display import Image, display
display(Image(filename="architecture.png"))

# %% [markdown]
# ### Exercises
# 1. Open JupyterLab, create a notebook, and use %timeit to compare list comprehension vs numpy for creating an array of 100,000 random numbers

# %%
import random
# %timeit [random.random() for i in range(100000)]
# %timeit np.random.random(100_000)

# %% [markdown]
# NumPy is roughly 10x faster because it's implemented in C and operates on contiguous memory blocks rather than Python objects one at a time.

# %% [markdown]
# 2. Create a notebook with both markdown and code cells that loads a CSV, displays a dataframe, and plots a chart. Then run Kernel > Restart & Run All to verify it works top to bottom

# %%
df = pd.read_csv("electricity.csv")
df.head(10)

# %%
plt.figure(figsize=(10, 8))
plt.plot(df["period"],df["nswprice"], label="NSW Price")
plt.plot(df['period'], df['vicprice'], label='VIC Price')
plt.legend()
plt.title('Electricity Price Over Time')

# %%
import seaborn as sns
sns.heatmap(df[['nswprice','nswdemand','vicprice','vicdemand','transfer']].corr(), annot=True)
